# %% [markdown]
# ## Scrapping migration flows data for The Bronx, New York
#
# This notebook scrapes data from the [US Census American Community Survey (ACS) Migration Flows API](https://www.census.gov/data/developers/data-sets/acs-migration-flows.html), which documents the estimate of movers between counties over a five-year period. This scrapper makes use of the US Census' 2018-2022 ACS data set.
#
# Although it accounts for some documented migrations from countries abroad, it does not account for all. It mainly documents state-to-county migrations, county-to-county migrations, and other smaller-scale migration flows (i.e., minor civil division (MCD) to minor civil division).
#
# Using this scrapper for other counties or states can be particularly helpful. However, this notebook focuses on The Bronx County in New York.

# %% [markdown]
# In the row below, we import the necessary libraries:

# %%
import requests 
import pandas as pd

# %% [markdown]
# In this line of code, we create a dictionary called "target_dict" that has the target variables [listed by the US Census](https://api.census.gov/data/2022/acs/flows/variables.html) as the dictonary keys. The dictionary values are the what we'll re-name the variables once they are scrapped and added onto a dataframe.

# %%
## create a dictionary to know what codes mean

target_dict = {
    "COUNTY1" : "reference_fips_county_code",
    "COUNTY1_NAME" : "reference_county_name",
    "STATE1_NAME" : "reference_state_name",
    "MCD1" : "reference_mcd_code",
    "MCD1_NAME" : "reference_mcd_name",
    "NONMOVERS" : "total_same_residence",
    "NONMOVERS_M" : "margin_error_same_residence", 
    "COUNTY2" : "migrated_from_county_code",
    "COUNTY2_NAME" : "migrated_from_county_name",
    "STATE2_NAME" : "migrated_from_location_name", 
    "FROMABROAD" : "county_total_movers_from_abroad",
    "FROMABROAD_M" : "margin_error_movers_from_abroad",
    "FROMDIFFCTY" : "county_total_movers_diff_county",
    "FROMDIFFCTY_M" : "margin_error_movers_diff_county",
    "FROMDIFFMCD" : "county_total_movers_diff_mcd",
    "FROMDIFFMCD_M" : "margin_error_movers_diff_mcd",
    "FROMDIFFMETRO" : "county_total_movers_diff_metro",
    "FROMDIFFMETRO_M" : "margin_error_diff_metro_area",
    "FROMDIFFSTATE" : "county_total_movers_diff_state",
    "FROMDIFFSTATE_M" : "margin_error_diff_state",
    "FROMELSEWHEREUSPR" : "county_total_movers_diff_country",
    "FROMELSEWHEREUSPR_M" : "margin_error_diff_country", 
    
}

# %% [markdown]
# In the cells below, we are adding our "target_dict" keys into a variable called "target_variables" which will be used to call up our API request later in the notebook.

# %%
type(target_dict.keys())
# Out:
# dict_keys

# %%
target_variables = ",".join(target_dict.keys())
target_variables
# Out:
# 'COUNTY1,COUNTY1_NAME,STATE1_NAME,MCD1,MCD1_NAME,NONMOVERS,NONMOVERS_M,COUNTY2,COUNTY2_NAME,STATE2_NAME,FROMABROAD,FROMABROAD_M,FROMDIFFCTY,FROMDIFFCTY_M,FROMDIFFMCD,FROMDIFFMCD_M,FROMDIFFMETRO,FROMDIFFMETRO_M,FROMDIFFSTATE,FROMDIFFSTATE_M,FROMELSEWHEREUSPR,FROMELSEWHEREUSPR_M'

# %% [markdown]
# Below we are piecing together the components that will make our API request, including:
# - a base_url.
# - a target_county variable that could be substituted with another county FIPS code (not The Bronx) when needed.
# - a target_state variable that could be substituted with another state FIPS code (not New York) when needed.

# %%
base_url = "https://api.census.gov/data/2022/acs/flows?"
target_county = "005"
target_state = "36"

# %% [markdown]
# Here we are creating our query_string which will input the values for target_county and target_state from the previous cell.

# %%
query_string = f"get={target_variables}&for=county:{target_county}&in=state:{target_state}"
query_string
# Out:
# 'get=COUNTY1,COUNTY1_NAME,STATE1_NAME,MCD1,MCD1_NAME,NONMOVERS,NONMOVERS_M,COUNTY2,COUNTY2_NAME,STATE2_NAME,FROMABROAD,FROMABROAD_M,FROMDIFFCTY,FROMDIFFCTY_M,FROMDIFFMCD,FROMDIFFMCD_M,FROMDIFFMETRO,FROMDIFFMETRO_M,FROMDIFFSTATE,FROMDIFFSTATE_M,FROMELSEWHEREUSPR,FROMELSEWHEREUSPR_M&for=county:005&in=state:36'

# %% [markdown]
# Before continuing, we must hide our US Census API key to ensure it is not publicly accessible and used without our permission. This is done by importing load_dotenv and saving the API key as .env file in the same location as this notebook.

# %%
pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in /Users/gabrielaflores/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages (1.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
##Hiding my key
import os
from dotenv import load_dotenv 
load_dotenv()
# Out:
# True

# %%
census_api_key = os.getenv("CENSUS_API_KEY")

# %%
api_parameter = f"&key={census_api_key}"
api_parameter
# Out:
# '&key=INSERT CENSUS API KEY'

# %% [markdown]
# Finally, we are assembling our endpoint in the cell below:

# %%
endpoint = base_url + query_string + api_parameter
endpoint
# Out:
# 'https://api.census.gov/data/2022/acs/flows?get=COUNTY1,COUNTY1_NAME,STATE1_NAME,MCD1,MCD1_NAME,NONMOVERS,NONMOVERS_M,COUNTY2,COUNTY2_NAME,STATE2_NAME,FROMABROAD,FROMABROAD_M,FROMDIFFCTY,FROMDIFFCTY_M,FROMDIFFMCD,FROMDIFFMCD_M,FROMDIFFMETRO,FROMDIFFMETRO_M,FROMDIFFSTATE,FROMDIFFSTATE_M,FROMELSEWHEREUSPR,FROMELSEWHEREUSPR_M&for=county:005&in=state:36&key=INSERT CENSUS API KEY'

# %% [markdown]
# To ensure the endpoint is accessible and the request is valid, we check the API's response status in the line below:

# %%
response = requests.get(endpoint)
response.status_code
# Out:
# 200

# %% [markdown]
# Next, we're converting the endpoint's response into JSON and storing it under "data." Then we are calling up all the rows after the first row:

# %%
data = response.json ()
data[1:]
# Out:
# [['005',
#   'Bronx County',
#   'New York',
#   None,
#   None,
#   '1310403',
#   '4638',
#   None,
#   None,
#   'Alabama',
#   '9919',
#   '1396',
#   '31106',
#   '2730',
#   None,
#   None,
#   None,
#   None,
#   '8544',
#   '1037',
#   '103902',
#   '4627',
#   '36',
#   '005'],
#  ['005',
#   'Bronx County',
#   'New York',
#   None,
#   None,
#   '1310403',
#   '4638',
#   None,
#   None,
#   'Arizona',
#   '9919',
#   '1396',
#   '31106',
#   '2730',
#   None,
#   None,
#   None,
#   None,
#   '8544',
#   '1037',
#   '103902',
#   '4627',
#   '36',
#   '005'],
#  ['005',
#   'Bronx County',
#   'New York',
#   None,
#   None,
#   '1310403',
#   '4638',
#   None,
#   None,
#   'California',
#   '9919',
#   '1396',
#   '31106',
#   '2730',
#   None,
#   None,
#   None,
#   None,
#   '8544',
#   '1037',
#   '103902',
#   '4627',
#   '36',
#   '005'],
#  ['005',
#   'Bronx County',
#   'New York',
#   None,
#   None,
#   '1310403',
#   '4638',
#   None,
#   None,
#   'Colorado',
#   '9919',
#   '1396',
#   '31106',
#   '2730',
#   None,
#   None,
#   None,
#   None,
#   '8544',
#   '1037',
#   '103902',
#   '4627',
#   '36',
#   '005'],
#  ['005',
#   'Bronx County',
#   'New York',
#   None,
#   None,
#   '1310403',
#   '4638',
#   None,
#   None,
#   'Delaware',
#   '9919',
#   '1396',
#   '31106',
#   '2730',
#   None,
#   None,
#   None,
#   None,
#   '8544',
#   '1037',
#   '103902',
#   '4627',
#   '36',
#   '005'],
#  ['005',
#   'Bronx County',
#   'New York',
#   None,
#   None,
#   '1310403',
#   '4638',
#   None,
#   None,
#   'District of Columbia',
#   '9919',
#   '1396',
#   '31106',
#   '2730',
#   None,
#   None,
#   None,
#   None,
#   '8544',
#   '1037',
#   '103902',
#   '4627',
#   '36',
#   '005'],
#  ['005',
#   'Bronx County',
#   'New York',
#   None,
#   None,
#   '1310403',
#   '4638',
#   None,
#   None,
#   'Florida',
#   '9919',
#   '1396',
#   '31106',
#   '2730',
#   None,
#   None,
#   None,
#   None,
#   '8544',
#   '1037',
#   '103902',
#   '4627',
#   '36',
#   '005'],
#  ['005',
#   'Bronx County',
#   'New York',
#   None,
#   None,
#   '1310403',
#   '4638',
#   None,
#   None,
#   'Georgia',
#   '9919',
#   '1396',
#   '31106',
#   '2730',
#   None,
#   None,
#   None,
#   None,
#   '8544',
#   '1037',
#   '103902',
#   '4627',
#   '36',
#   '005'],
#  ['005',
#   'Bronx County',
#   'New York',
#   None,
#   None,
#   '1310403',
#   '4638',
#   None,
#   None,
#   'Illinois',
#   '9919',
#   '1396',
#   '31106',
#   '2730',
#   None,
#   None,
#   None,
#   None,
#   '8544',
#   '1037',
#   '103902',
#   '4627',
#   '36',
#   '005'],
#  ['005',
#   'Bronx County',
#   'New York',
#   None,
#   None,
#   '1310403',
#   '4638',
#   None,
#   None,
#   'Indiana',
#   '9919',
#   '1396',
#   '31106',
#   '2730',
#   None,
#   None,
#   None,
#   None,
#   '8544',
#   '1037',
#   '103902',
#   '4627',
#   '36',
#   '005'],
#  ['005',
#   'Bronx County',
#   'New York',
#   None,
#   None,
#   '1310403',
#   '4638',
#   None,
#   None,
#   'Iowa',
#   '9919',
#   '1396',
#   '31106',
#   '2730',
#   None,
#   None,
#   None,
#   None,
#   '8544',
#   '1037',
#   '103902',
#   '4627',
#   '36',
#   '005'],
#  ['005',
#   'Bronx County',
#   'New York',
#   None,
#   None,
#   '1310403',
#   '4638',
#   None,
#   None,
#   'Kansas',
#   '9919',
#   '1396',
#   '31106',
#   '2730',
#   None,
#   None,
#   None,
#   None,
#   '8544',
#   '1037',
#   '103902',
#   '4627',
#   '36',
#   '005'],
#  ['005',
#   'Bronx County',
#   'New York',
#   None,
#   None,
#   '1310403',
#   '4638',
#   None,
#   None,
#   'Kentucky',
#   '9919',
#   '1396',
#   '31106',
#   '2730',
#   None,
#   None,
#   None,
#   None,
#   '8544',
#   '1037',
#   '103902',
#   '4627',
#   '36',
#   '005'],
#  ['005',
#   'Bronx County',
#   'New York',
#   None,
#   None,
#   '1310403',
#   '4638',
#   None,
#   None,
#   'Louisiana',
#   '9919',
#   '1396',
#   '31106',
#   '2730',
#   None,
#   None,
#   None,
#   None,
#   '8544',
#   '1037',
#   '103902',
#   '4627',
#   '36',
#   '005'],
#  ['005',
#   'Bronx County',
#   'New York',
#   None,
#   None,
#   '1310403',
#   '4638',
#   None,
#   None,
#   'Maine',
#   '9919',
#   '1396',
#   '31106',
#   '2730',
#   None,
#   None,
#   None,
#   None,
#   '8544',
#   '1037',
#   '103902',
#   '4627',
#   '36',
#   '005'],
#  ['005',
#   'Bronx County',
#   'New York',
#   None,
#   None,
#   '1310403',
#   '4638',
#   None,
#   None,
#   'Maryland',
#   '9919',
#   '1396',
#   '31106',
#   '2730',
#   None,
#   None,
#   None,
#   None,
#   '8544',
#   '1037',
#   '103902',
#   '4627',
#   '36',
#   '005'],
#  ['005',
#   'Bronx County',
#   'New York',
#   None,
#   None,
#   '1310403',
#   '4638',
#   None,
#   None,
#   'Massachusetts',
#   '9919',
#   '1396',
#   '31106',
#   '2730',
#   None,
#   None,
#   None,
#   None,
#   '8544',
#   '1037',
#   '103902',
#   '4627',
#   '36',
#   '005'],
#  ['005',
#   'Bronx County',
#   'New York',
#   None,
#   None,
#   '1310403',
#   '4638',
#   None,
#   None,
#   'Michigan',
#   '9919',
#   '1396',
#   '31106',
#   '2730',
#   None,
#   None,
#   None,
#   None,
#   '8544',
#   '1037',
#   '103902',
#   '4627',
#   '36',
#   '005'],
#  ['005',
#   'Bronx County',
#   'New York',
#   None,
#   None,
#   '1310403',
#   '4638',
#   None,
#   None,
#   'Minnesota',
#   '9919',
#   '1396',
#   '31106',
#   '2730',
#   None,
#   None,
#   None,
#   None,
#   '8544',
#   '1037',
#   '103902',
#   '4627',
#   '36',
#   '005'],
#  ['005',
#   'Bronx County',
#   'New York',
#   None,
#   None,
#   '1310403',
#   '4638',
#   None,
#   None,
#   'Missouri',
#   '9919',
#   '1396',
#   '31106',
#   '2730',
#   None,
#   None,
#   None,
#   None,
#   '8544',
#   '1037',
#   '103902',
#   '4627',
#   '36',
#   '005'],
#  ['005',
#   'Bronx County',
#   'New York',
#   None,
#   None,
#   '1310403',
#   '4638',
#   None,
#   None,
#   'Nebraska',
#   '9919',
#   '1396',
#   '31106',
#   '2730',
#   None,
#   None,
#   None,
#   None,
#   '8544',
#   '1037',
#   '103902',
#   '4627',
#   '36',
#   '005'],
#  ['005',
#   'Bronx County',
#   'New York',
#   None,
#   None,
#   '1310403',
#   '4638',
#   None,
#   None,
#   'Nevada',
#   '9919',
#   '1396',
#   '31106',
#   '2730',
#   None,
#   None,
#   None,
#   None,
#   '8544',
#   '1037',
#   '103902',
#   '4627',
#   '36',
#   '005'],
#  ['005',
#   'Bronx County',
#   'New York',
#   None,
#   None,
#   '1310403',
#   '4638',
#   None,
#   None,
#   'New Jersey',
#   '9919',
#   '1396',
#   '31106',
#   '2730',
#   None,
#   None,
#   None,
#   None,
#   '8544',
#   '1037',
#   '103902',
#   '4627',
#   '36',
#   '005'],
#  ['005',
#   'Bronx County',
#   'New York',
#   None,
#   None,
#   '1310403',
#   '4638',
#   None,
#   None,
#   'New Mexico',
#   '9919',
#   '1396',
#   '31106',
#   '2730',
#   None,
#   None,
#   None,
#   None,
#   '8544',
#   '1037',
#   '103902',
#   '4627',
#   '36',
#   '005'],
#  ['005',
#   'Bronx County',
#   'New York',
#   None,
#   None,
#   '1310403',
#   '4638',
#   None,
#   None,
#   'New York',
#   '9919',
#   '1396',
#   '31106',
#   '2730',
#   None,
#   None,
#   None,
#   None,
#   '8544',
#   '1037',
#   '103902',
#   '4627',
#   '36',
#   '005'],
#  ['005',
#   'Bronx County',
#   'New York',
#   None,
#   None,
#   '1310403',
#   '4638',
#   None,
#   None,
#   'North Carolina',
#   '9919',
#   '1396',
#   '31106',
#   '2730',
#   None,
#   None,
#   None,
#   None,
#   '8544',
#   '1037',
#   '103902',
#   '4627',
#   '36',
#   '005'],
#  ['005',
#   'Bronx County',
#   'New York',
#   None,
#   None,
#   '1310403',
#   '4638',
#   None,
#   None,
#   'North Dakota',
#   '9919',
#   '1396',
#   '31106',
#   '2730',
#   None,
#   None,
#   None,
#   None,
#   '8544',
#   '1037',
#   '103902',
#   '4627',
#   '36',
#   '005'],
#  ['005',
#   'Bronx County',
#   'New York',
#   None,
#   None,
#   '1310403',
#   '4638',
#   None,
#   None,
#   'Ohio',
#   '9919',
#   '1396',
#   '31106',
#   '2730',
#   None,
#   None,
#   None,
#   None,
#   '8544',
#   '1037',
#   '103902',
#   '4627',
#   '36',
#   '005'],
#  ['005',
#   'Bronx County',
#   'New York',
#   None,
#   None,
#   '1310403',
#   '4638',
#   None,
#   None,
#   'Oklahoma',
#   '9919',
#   '1396',
#   '31106',
#   '2730',
#   None,
#   None,
#   None,
#   None,
#   '8544',
#   '1037',
#   '103902',
#   '4627',
#   '36',
#   '005'],
#  ['005',
#   'Bronx County',
#   'New York',
#   None,
#   None,
#   '1310403',
#   '4638',
#   None,
#   None,
#   'Oregon',
#   '9919',
#   '1396',
#   '31106',
#   '2730',
#   None,
#   None,
#   None,
#   None,
#   '8544',
#   '1037',
#   '103902',
#   '4627',
#   '36',
#   '005'],
#  ['005',
#   'Bronx County',
#   'New York',
#   None,
#   None,
#   '1310403',
#   '4638',
#   None,
#   None,
#   'Pennsylvania',
#   '9919',
#   '1396',
#   '31106',
#   '2730',
#   None,
#   None,
#   None,
#   None,
#   '8544',
#   '1037',
#   '103902',
#   '4627',
#   '36',
#   '005'],
#  ['005',
#   'Bronx County',
#   'New York',
#   None,
#   None,
#   '1310403',
#   '4638',
#   None,
#   None,
#   'Rhode Island',
#   '9919',
#   '1396',
#   '31106',
#   '2730',
#   None,
#   None,
#   None,
#   None,
#   '8544',
#   '1037',
#   '103902',
#   '4627',
#   '36',
#   '005'],
#  ['005',
#   'Bronx County',
#   'New York',
#   None,
#   None,
#   '1310403',
#   '4638',
#   None,
#   None,
#   'South Carolina',
#   '9919',
#   '1396',
#   '31106',
#   '2730',
#   None,
#   None,
#   None,
#   None,
#   '8544',
#   '1037',
#   '103902',
#   '4627',
#   '36',
#   '005'],
#  ['005',
#   'Bronx County',
#   'New York',
#   None,
#   None,
#   '1310403',
#   '4638',
#   None,
#   None,
#   'Tennessee',
#   '9919',
#   '1396',
#   '31106',
#   '2730',
#   None,
#   None,
#   None,
#   None,
#   '8544',
#   '1037',
#   '103902',
#   '4627',
#   '36',
#   '005'],
#  ['005',
#   'Bronx County',
#   'New York',
#   None,
#   None,
#   '1310403',
#   '4638',
#   None,
#   None,
#   'Texas',
#   '9919',
#   '1396',
#   '31106',
#   '2730',
#   None,
#   None,
#   None,
#   None,
#   '8544',
#   '1037',
#   '103902',
#   '4627',
#   '36',
#   '005'],
#  ['005',
#   'Bronx County',
#   'New York',
#   None,
#   None,
#   '1310403',
#   '4638',
#   None,
#   None,
#   'Virginia',
#   '9919',
#   '1396',
#   '31106',
#   '2730',
#   None,
#   None,
#   None,
#   None,
#   '8544',
#   '1037',
#   '103902',
#   '4627',
#   '36',
#   '005'],
#  ['005',
#   'Bronx County',
#   'New York',
#   None,
#   None,
#   '1310403',
#   '4638',
#   None,
#   None,
#   'Washington',
#   '9919',
#   '1396',
#   '31106',
#   '2730',
#   None,
#   None,
#   None,
#   None,
#   '8544',
#   '1037',
#   '103902',
#   '4627',
#   '36',
#   '005'],
#  ['005',
#   'Bronx County',
#   'New York',
#   None,
#   None,
#   '1310403',
#   '4638',
#   None,
#   None,
#   'West Virginia',
#   '9919',
#   '1396',
#   '31106',
#   '2730',
#   None,
#   None,
#   None,
#   None,
#   '8544',
#   '1037',
#   '103902',
#   '4627',
#   '36',
#   '005'],
#  ['005',
#   'Bronx County',
#   'New York',
#   None,
#   None,
#   '1310403',
#   '4638',
#   None,
#   None,
#   'Puerto Rico',
#   '9919',
#   '1396',
#   '31106',
#   '2730',
#   None,
#   None,
#   None,
#   None,
#   '8544',
#   '1037',
#   '103902',
#   '4627',
#   '36',
#   '005'],
#  ['005',
#   'Bronx County',
#   'New York',
#   None,
#   None,
#   '1310403',
#   '4638',
#   None,
#   None,
#   'Africa',
#   '9919',
#   '1396',
#   '31106',
#   '2730',
#   None,
#   None,
#   None,
#   None,
#   '8544',
#   '1037',
#   '103902',
#   '4627',
#   '36',
#   '005'],
#  ['005',
#   'Bronx County',
#   'New York',
#   None,
#   None,
#   '1310403',
#   '4638',
#   None,
#   None,
#   'Asia',
#   '9919',
#   '1396',
#   '31106',
#   '2730',
#   None,
#   None,
#   None,
#   None,
#   '8544',
#   '1037',
#   '103902',
#   '4627',
#   '36',
#   '005'],
#  ['005',
#   'Bronx County',
#   'New York',
#   None,
#   None,
#   '1310403',
#   '4638',
#   None,
#   None,
#   'Central America',
#   '9919',
#   '1396',
#   '31106',
#   '2730',
#   None,
#   None,
#   None,
#   None,
#   '8544',
#   '1037',
#   '103902',
#   '4627',
#   '36',
#   '005'],
#  ['005',
#   'Bronx County',
#   'New York',
#   None,
#   None,
#   '1310403',
#   '4638',
#   None,
#   None,
#   'Caribbean',
#   '9919',
#   '1396',
#   '31106',
#   '2730',
#   None,
#   None,
#   None,
#   None,
#   '8544',
#   '1037',
#   '103902',
#   '4627',
#   '36',
#   '005'],
#  ['005',
#   'Bronx County',
#   'New York',
#   None,
#   None,
#   '1310403',
#   '4638',
#   None,
#   None,
#   'Europe',
#   '9919',
#   '1396',
#   '31106',
#   '2730',
#   None,
#   None,
#   None,
#   None,
#   '8544',
#   '1037',
#   '103902',
#   '4627',
#   '36',
#   '005'],
#  ['005',
#   'Bronx County',
#   'New York',
#   None,
#   None,
#   '1310403',
#   '4638',
#   None,
#   None,
#   'U.S. Island Areas',
#   '9919',
#   '1396',
#   '31106',
#   '2730',
#   None,
#   None,
#   None,
#   None,
#   '8544',
#   '1037',
#   '103902',
#   '4627',
#   '36',
#   '005'],
#  ['005',
#   'Bronx County',
#   'New York',
#   None,
#   None,
#   '1310403',
#   '4638',
#   None,
#   None,
#   'Northern America',
#   '9919',
#   '1396',
#   '31106',
#   '2730',
#   None,
#   None,
#   None,
#   None,
#   '8544',
#   '1037',
#   '103902',
#   '4627',
#   '36',
#   '005'],
#  ['005',
#   'Bronx County',
#   'New York',
#   None,
#   None,
#   '1310403',
#   '4638',
#   None,
#   None,
#   'South America',
#   '9919',
#   '1396',
#   '31106',
#   '2730',
#   None,
#   None,
#   None,
#   None,
#   '8544',
#   '1037',
#   '103902',
#   '4627',
#   '36',
#   '005']]

# %% [markdown]
# To make the scrapped information more comprehensible, we are adding it into a dataframe and renaming it's columns to the values listed in the "target_dict" variable:

# 4             103902                4627    36    005
# 5             103902                4627    36    005
# 6             103902                4627    36    005
# 7             103902                4627    36    005
# 8             103902                4627    36    005
# 9             103902                4627    36    005
# 10            103902                4627    36    005
# 11            103902                4627    36    005
# 12            103902                4627    36    005
# 13            103902                4627    36    005
# 14            103902                4627    36    005
# 15            103902                4627    36    005
# 16            103902                4627    36    005
# 17            103902                4627    36    005
# 18            103902                4627    36    005
# 19            103902                4627    36    005
# 20            103902                4627    36    005
# 21            103902                4627    36    005
# 22            103902                4627    36    005
# 23            103902                4627    36    005
# 24            103902                4627    36    005
# 25            103902                4627    36    005
# 26            103902                4627    36    005
# 27            103902                4627    36    005
# 28            103902                4627    36    005
# 29            103902                4627    36    005
# 30            103902                4627    36    005
# 31            103902                4627    36    005
# 32            103902                4627    36    005
# 33            103902                4627    36    005
# 34            103902                4627    36    005
# 35            103902                4627    36    005
# 36            103902                4627    36    005
# 37            103902                4627    36    005
# 38            103902                4627    36    005
# 39            103902                4627    36    005
# 40            103902                4627    36    005
# 41            103902                4627    36    005
# 42            103902                4627    36    005
# 43            103902                4627    36    005
# 44            103902                4627    36    005
# 45            103902                4627    36    005
# 46            103902                4627    36    005
#
# [47 rows x 24 columns]

# %%
df_bronx = df.rename(columns = target_dict)
df_bronx
# Out:
#    reference_fips_county_code reference_county_name reference_state_name  \
# 0                         005          Bronx County             New York
# 1                         005          Bronx County             New York
# 2                         005          Bronx County             New York
# 3                         005          Bronx County             New York
# 4                         005          Bronx County             New York
# 5                         005          Bronx County             New York
# 6                         005          Bronx County             New York
# 7                         005          Bronx County             New York
# 8                         005          Bronx County             New York
# 9                         005          Bronx County             New York
# 10                        005          Bronx County             New York
# 11                        005          Bronx County             New York
# 12                        005          Bronx County             New York
# 13                        005          Bronx County             New York
# 14                        005          Bronx County             New York
# 15                        005          Bronx County             New York
# 16                        005          Bronx County             New York
# 17                        005          Bronx County             New York
# 18                        005          Bronx County             New York
# 19                        005          Bronx County             New York
# 20                        005          Bronx County             New York
# 21                        005          Bronx County             New York
# 22                        005          Bronx County             New York
# 23                        005          Bronx County             New York
# 24                        005          Bronx County             New York
# 25                        005          Bronx County             New York
# 26                        005          Bronx County             New York
# 27                        005          Bronx County             New York
# 28                        005          Bronx County             New York
# 29                        005          Bronx County             New York
# 30                        005          Bronx County             New York
# 31                        005          Bronx County             New York
# 32                        005          Bronx County             New York
# 33                        005          Bronx County             New York
# 34                        005          Bronx County             New York
# 35                        005          Bronx County             New York
# 36                        005          Bronx County             New York
# 37                        005          Bronx County             New York
# 38                        005          Bronx County             New York
# 39                        005          Bronx County             New York
# 40                        005          Bronx County             New York
# 41                        005          Bronx County             New York
# 42                        005          Bronx County             New York
# 43                        005          Bronx County             New York
# 44                        005          Bronx County             New York
# 45                        005          Bronx County             New York
# 46                        005          Bronx County             New York
#
#    reference_mcd_code reference_mcd_name total_same_residence  \
# 0                None               None              1310403
# 1                None               None              1310403
# 2                None               None              1310403
# 3                None               None              1310403
# 4                None               None              1310403
# 5                None               None              1310403
# 6                None               None              1310403
# 7                None               None              1310403
# 8                None               None              1310403
# 9                None               None              1310403
# 10               None               None              1310403
# 11               None               None              1310403
# 12               None               None              1310403
# 13               None               None              1310403
# 14               None               None              1310403
# 15               None               None              1310403
# 16               None               None              1310403
# 17               None               None              1310403
# 18               None               None              1310403
# 19               None               None              1310403
# 20               None               None              1310403
# 21               None               None              1310403
# 22               None               None              1310403
# 23               None               None              1310403
# 24               None               None              1310403
# 25               None               None              1310403
# 26               None               None              1310403
# 27               None               None              1310403
# 28               None               None              1310403
# 29               None               None              1310403
# 30               None               None              1310403
# 31               None               None              1310403
# 32               None               None              1310403
# 33               None               None              1310403
# 34               None               None              1310403
# 35               None               None              1310403
# 36               None               None              1310403
# 37               None               None              1310403
# 38               None               None              1310403
# 39               None               None              1310403
# 40               None               None              1310403
# 41               None               None              1310403
# 42               None               None              1310403
# 43               None               None              1310403
# 44               None               None              1310403
# 45               None               None              1310403
# 46               None               None              1310403
#
#    margin_error_same_residence migrated_from_county_code  \
# 0                         4638                      None
# 1                         4638                      None
# 2                         4638                      None
# 3                         4638                      None
# 4                         4638                      None
# 5                         4638                      None
# 6                         4638                      None
# 7                         4638                      None
# 8                         4638                      None
# 9                         4638                      None
# 10                        4638                      None
# 11                        4638                      None
# 12                        4638                      None
# 13                        4638                      None
# 14                        4638                      None
# 15                        4638                      None
# 16                        4638                      None
# 17                        4638                      None
# 18                        4638                      None
# 19                        4638                      None
# 20                        4638                      None
# 21                        4638                      None
# 22                        4638                      None
# 23                        4638                      None
# 24                        4638                      None
# 25                        4638                      None
# 26                        4638                      None
# 27                        4638                      None
# 28                        4638                      None
# 29                        4638                      None
# 30                        4638                      None
# 31                        4638                      None
# 32                        4638                      None
# 33                        4638                      None
# 34                        4638                      None
# 35                        4638                      None
# 36                        4638                      None
# 37                        4638                      None
# 38                        4638                      None
# 39                        4638                      None
# 40                        4638                      None
# 41                        4638                      None
# 42                        4638                      None
# 43                        4638                      None
# 44                        4638                      None
# 45                        4638                      None
# 46                        4638                      None
#
#    migrated_from_county_name migrated_from_location_name  ...  \
# 0                       None                     Alabama  ...
# 1                       None                     Arizona  ...
# 2                       None                  California  ...
# 3                       None                    Colorado  ...
# 4                       None                    Delaware  ...
# 5                       None        District of Columbia  ...
# 6                       None                     Florida  ...
# 7                       None                     Georgia  ...
# 8                       None                    Illinois  ...
# 9                       None                     Indiana  ...
# 10                      None                        Iowa  ...
# 11                      None                      Kansas  ...
# 12                      None                    Kentucky  ...
# 13                      None                   Louisiana  ...
# 14                      None                       Maine  ...
# 15                      None                    Maryland  ...
# 16                      None               Massachusetts  ...
# 17                      None                    Michigan  ...
# 18                      None                   Minnesota  ...
# 19                      None                    Missouri  ...
# 20                      None                    Nebraska  ...
# 21                      None                      Nevada  ...
# 22                      None                  New Jersey  ...
# 23                      None                  New Mexico  ...
# 24                      None                    New York  ...
# 25                      None              North Carolina  ...
# 26                      None                North Dakota  ...
# 27                      None                        Ohio  ...
# 28                      None                    Oklahoma  ...
# 29                      None                      Oregon  ...
# 30                      None                Pennsylvania  ...
# 31                      None                Rhode Island  ...
# 32                      None              South Carolina  ...
# 33                      None                   Tennessee  ...
# 34                      None                       Texas  ...
# 35                      None                    Virginia  ...
# 36                      None                  Washington  ...
# 37                      None               West Virginia  ...
# 38                      None                 Puerto Rico  ...
# 39                      None                      Africa  ...
# 40                      None                        Asia  ...
# 41                      None             Central America  ...
# 42                      None                   Caribbean  ...
# 43                      None                      Europe  ...
# 44                      None           U.S. Island Areas  ...
# 45                      None            Northern America  ...
# 46                      None               South America  ...
#
#    county_total_movers_diff_mcd margin_error_movers_diff_mcd  \
# 0                          None                         None
# 1                          None                         None
# 2                          None                         None
# 3                          None                         None
# 4                          None                         None
# 5                          None                         None
# 6                          None                         None
# 7                          None                         None
# 8                          None                         None
# 9                          None                         None
# 10                         None                         None
# 11                         None                         None
# 12                         None                         None
# 13                         None                         None
# 14                         None                         None
# 15                         None                         None
# 16                         None                         None
# 17                         None                         None
# 18                         None                         None
# 19                         None                         None
# 20                         None                         None
# 21                         None                         None
# 22                         None                         None
# 23                         None                         None
# 24                         None                         None
# 25                         None                         None
# 26                         None                         None
# 27                         None                         None
# 28                         None                         None
# 29                         None                         None
# 30                         None                         None
# 31                         None                         None
# 32                         None                         None
# 33                         None                         None
# 34                         None                         None
# 35                         None                         None
# 36                         None                         None
# 37                         None                         None
# 38                         None                         None
# 39                         None                         None
# 40                         None                         None
# 41                         None                         None
# 42                         None                         None
# 43                         None                         None
# 44                         None                         None
# 45                         None                         None
# 46                         None                         None
#
#    county_total_movers_diff_metro margin_error_diff_metro_area  \
# 0                            None                         None
# 1                            None                         None
# 2                            None                         None
# 3                            None                         None
# 4                            None                         None
# 5                            None                         None
# 6                            None                         None
# 7                            None                         None
# 8                            None                         None
# 9                            None                         None
# 10                           None                         None
# 11                           None                         None
# 12                           None                         None
# 13                           None                         None
# 14                           None                         None
# 15                           None                         None
# 16                           None                         None
# 17                           None                         None
# 18                           None                         None
# 19                           None                         None
# 20                           None                         None
# 21                           None                         None
# 22                           None                         None
# 23                           None                         None
# 24                           None                         None
# 25                           None                         None
# 26                           None                         None
# 27                           None                         None
# 28                           None                         None
# 29                           None                         None
# 30                           None                         None
# 31                           None                         None
# 32                           None                         None
# 33                           None                         None
# 34                           None                         None
# 35                           None                         None
# 36                           None                         None
# 37                           None                         None
# 38                           None                         None
# 39                           None                         None
# 40                           None                         None
# 41                           None                         None
# 42                           None                         None
# 43                           None                         None
# 44                           None                         None
# 45                           None                         None
# 46                           None                         None
#
#    county_total_movers_diff_state margin_error_diff_state  \
# 0                            8544                    1037
# 1                            8544                    1037
# 2                            8544                    1037
# 3                            8544                    1037
# 4                            8544                    1037
# 5                            8544                    1037
# 6                            8544                    1037
# 7                            8544                    1037
# 8                            8544                    1037
# 9                            8544                    1037
# 10                           8544                    1037
# 11                           8544                    1037
# 12                           8544                    1037
# 13                           8544                    1037
# 14                           8544                    1037
# 15                           8544                    1037
# 16                           8544                    1037
# 17                           8544                    1037
# 18                           8544                    1037
# 19                           8544                    1037
# 20                           8544                    1037
# 21                           8544                    1037
# 22                           8544                    1037
# 23                           8544                    1037
# 24                           8544                    1037
# 25                           8544                    1037
# 26                           8544                    1037
# 27                           8544                    1037
# 28                           8544                    1037
# 29                           8544                    1037
# 30                           8544                    1037
# 31                           8544                    1037
# 32                           8544                    1037
# 33                           8544                    1037
# 34                           8544                    1037
# 35                           8544                    1037
# 36                           8544                    1037
# 37                           8544                    1037
# 38                           8544                    1037
# 39                           8544                    1037
# 40                           8544                    1037
# 41                           8544                    1037
# 42                           8544                    1037
# 43                           8544                    1037
# 44                           8544                    1037
# 45                           8544                    1037
# 46                           8544                    1037
#
#    county_total_movers_diff_country margin_error_diff_country state county
# 0                            103902                      4627    36    005
# 1                            103902                      4627    36    005
# 2                            103902                      4627    36    005
# 3                            103902                      4627    36    005
# 4                            103902                      4627    36    005
# 5                            103902                      4627    36    005
# 6                            103902                      4627    36    005
# 7                            103902                      4627    36    005
# 8                            103902                      4627    36    005
# 9                            103902                      4627    36    005
# 10                           103902                      4627    36    005
# 11                           103902                      4627    36    005
# 12                           103902                      4627    36    005
# 13                           103902                      4627    36    005
# 14                           103902                      4627    36    005
# 15                           103902                      4627    36    005
# 16                           103902                      4627    36    005
# 17                           103902                      4627    36    005
# 18                           103902                      4627    36    005
# 19                           103902                      4627    36    005
# 20                           103902                      4627    36    005
# 21                           103902                      4627    36    005
# 22                           103902                      4627    36    005
# 23                           103902                      4627    36    005
# 24                           103902                      4627    36    005
# 25                           103902                      4627    36    005
# 26                           103902                      4627    36    005
# 27                           103902                      4627    36    005
# 28                           103902                      4627    36    005
# 29                           103902                      4627    36    005
# 30                           103902                      4627    36    005
# 31                           103902                      4627    36    005
# 32                           103902                      4627    36    005
# 33                           103902                      4627    36    005
# 34                           103902                      4627    36    005
# 35                           103902                      4627    36    005
# 36                           103902                      4627    36    005
# 37                           103902                      4627    36    005
# 38                           103902                      4627    36    005
# 39                           103902                      4627    36    005
# 40                           103902                      4627    36    005
# 41                           103902                      4627    36    005
# 42                           103902                      4627    36    005
# 43                           103902                      4627    36    005
# 44                           103902                      4627    36    005
# 45                           103902                      4627    36    005
# 46                           103902                      4627    36    005
#
# [47 rows x 24 columns]

# %% [markdown]
# Here we are counting the total number of movers who moved into The Bronx based on the state or location they lived in before:

# %%
df_bronx["migrated_from_location_name"].value_counts()
# Out:
# migrated_from_location_name
# Alabama                 1
# Virginia                1
# North Dakota            1
# Ohio                    1
# Oklahoma                1
# Oregon                  1
# Pennsylvania            1
# Rhode Island            1
# South Carolina          1
# Tennessee               1
# Texas                   1
# Washington              1
# New York                1
# West Virginia           1
# Puerto Rico             1
# Africa                  1
# Asia                    1
# Central America         1
# Caribbean               1
# Europe                  1
# U.S. Island Areas       1
# Northern America        1
# North Carolina          1
# New Mexico              1
# Arizona                 1
# Kansas                  1
# California              1
# Colorado                1
# Delaware                1
# District of Columbia    1
# Florida                 1
# Georgia                 1
# Illinois                1
# Indiana                 1
# Iowa                    1
# Kentucky                1
# New Jersey              1
# Louisiana               1
# Maine                   1
# Maryland                1
# Massachusetts           1
# Michigan                1
# Minnesota               1
# Missouri                1
# Nebraska                1
# Nevada                  1
# South America           1
# Name: count, dtype: int64

# %% [markdown]
# We saved our df_bronx dataframe into a csv file in our output folder:

# %%
df_bronx.to_csv("../output/bronx_migration_flows_2022.csv")
